# %% [markdown]
# # ***Engr.Muhammad Javed***

# %% [markdown]
# ## **Linear Regression:**

# %% [markdown]
# ## *Importing Required Libraries*

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder , StandardScaler , FunctionTransformer
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression , LinearRegression
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.feature_selection import SequentialFeatureSelector

# %% [markdown]
# ## *Loading the Dataset*

# %%
Dataset = pd.read_csv(r"E:\AI and Data Science\ML with Engr.Muhammad Javed\File\placement.csv")

# %% [markdown]
# ## *Show Dataset*

# %%
Dataset
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %% [markdown]
# ## *Checking Dataset Information*

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# ## *Viewing Statistical Summary of the Dataset*

# %%
Dataset.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %% [markdown]
# ## *Checking Missing Values in the Dataset*

# %%
Dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %% [markdown]
# ## *Visualizing Data Distribution Using Seaborn Distplot*

# %%
sn.distplot(Dataset["cgpa"])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_27580\3608002080.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(Dataset["cgpa"])

# %% [markdown]
# ## *Visualizing Data Distribution Using Seaborn Distplot*

# %%
sn.distplot(Dataset["package"])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_27580\2104350657.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(Dataset["package"])

# %% [markdown]
# ## *Splitting Features and target Variable*

# %%
x = Dataset[["cgpa"]]
y = Dataset[["package"]]

# %%
x , y
# Out:
# (     cgpa
#  0    6.89
#  1    5.12
#  2    7.82
#  3    7.42
#  4    6.94
#  ..    ...
#  195  6.93
#  196  5.89
#  197  7.21
#  198  7.63
#  199  6.22
#
#  [200 rows x 1 columns],
#       package
#  0       3.26
#  1       1.98
#  2       3.25
#  3       3.67
#  4       3.57
#  ..       ...
#  195     2.46
#  196     2.57
#  197     3.24
#  198     3.96
#  199     2.33
#
#  [200 rows x 1 columns])

# %% [markdown]
# ## **Ways to Check Linearity**

# %%
plt.figure(figsize=(5,3))
sn.scatterplot(x = "cgpa" , y = "package" , data = Dataset )
plt.show()

# %% [markdown]
# ## *Splitting Features and target Variable*

# %%
x = Dataset[["cgpa"]]
y = Dataset[["package"]]

# %% [markdown]
# ## *Splitting Dataset into Training and Testing Sets*

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , random_state=60 , test_size=0.2)

# %%
LR = LinearRegression()
LR.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **Check and Predict**

# %%
LR.predict([[5.12]])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1.93494117]])

# %%
arr = LR.score(x_train , y_train) * 100
print("Accuracy : " , arr)
# Out:
# Accuracy :  76.97225232332951

# %%
Dataset.corr()
# Out:
#              cgpa   package
# cgpa     1.000000  0.880692
# package  0.880692  1.000000

# %%
LR.coef_
# Out:
# array([[0.57062955]])

# %%
LR.intercept_
# Out:
# array([-0.98668212])

# %%
y_pred = LR.predict(x)

# %%
plt.figure(figsize=(8,4))
sn.scatterplot(x="cgpa" , y = "package" , data = Dataset)
plt.plot(Dataset["cgpa"] , y_pred , color = "red" , linestyle = "--")
plt.legend(["orgs data" , "Predict Line"])
plt.show()

# %% [markdown]
# ## **Algorithm**
# - y = mx + c
